# %% [markdown]
# ## **Product histories**

# %%
import pandas as pd
import Pipeline

# %%
histories = Pipeline.Product_Histories()

# %%
DATA_PATH = '/Users/leonhagel/Documents/coding/github/mlim-g2/data/'
EXPORT_PATH = '/Users/leonhagel/Documents/coding/github/mlim-g2/export/'

# %%
files = {
    'data': [
        #DATA_PATH + 'baskets.parquet',
        #DATA_PATH + 'coupon_index.parquet', 
        #DATA_PATH + 'coupons.parquet', 
        DATA_PATH + 'merged.parquet',
        #DATA_PATH + 'clean.parquet'
    ]
}

# %%
histories.load(files)

# reduce file sizes
for name, df in histories.data.items():
    histories.data[name] = histories.reduce_data_size(histories.data[name])

# %%
histories.pipeline_histories()
# Out:
# /Applications/Conda/anaconda3/envs/mlim/lib/python3.8/site-packages/tqdm/std.py:699: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████| 1378720/1378720 [00:41<00:00, 33515.02it/s]
#                                               0  \
# 0                                        [-inf]
# 1     [-inf, 7.0, 11.0, 48.0, 61.0, 66.0, 81.0]
# 2                                        [-inf]
# 3                                        [-inf]
# 4                                        [-inf]
# ...                                         ...
# 1995                                     [-inf]
# 1996                                     [-inf]
# 1997                         [-inf, 37.0, 74.0]
# 1998                   [-inf, 12.0, 52.0, 54.0]
# 1999                                     [-inf]
#
#                                                       1  \
# 0                                                [-inf]
# 1     [-inf, 2.0, 6.0, 18.0, 20.0, 27.0, 29.0, 49.0,...
# 2     [-inf, 2.0, 3.0, 6.0, 7.0, 8.0, 9.0, 11.0, 13....
# 3                                                [-inf]
# 4                                                [-inf]
# ...                                                 ...
# 1995  [-inf, 1.0, 4.0, 8.0, 21.0, 23.0, 24.0, 25.0, ...
# 1996                                             [-inf]
# 1997                                             [-inf]
# 1998                [-inf, 8.0, 36.0, 44.0, 82.0, 85.0]
# 1999                                             [-inf]
#
#                                                       2       3  \
# 0                                                [-inf]  [-inf]
# 1                                                [-inf]  [-inf]
# 2                                                [-inf]  [-inf]
# 3                                                [-inf]  [-inf]
# 4     [-inf, 6.0, 15.0, 21.0, 22.0, 27.0, 28.0, 58.0...  [-inf]
# ...                                                 ...     ...
# 1995                                             [-inf]  [-inf]
# 1996                                             [-inf]  [-inf]
# 1997                                             [-inf]  [-inf]
# 1998                                             [-inf]  [-inf]
# 1999                                             [-inf]  [-inf]
#
#                                                       4  \
# 0     [-inf, 24.0, 40.0, 45.0, 51.0, 54.0, 58.0, 60....
# 1     [-inf, 5.0, 13.0, 21.0, 23.0, 30.0, 47.0, 69.0...
# 2                                                [-inf]
# 3                               [-inf, 7.0, 19.0, 27.0]
# 4                                                [-inf]
# ...                                                 ...
# 1995                                             [-inf]
# 1996                                             [-inf]
# 1997                                             [-inf]
# 1998                                 [-inf, 56.0, 61.0]
# 1999  [-inf, 0.0, 4.0, 8.0, 12.0, 14.0, 20.0, 28.0, ...
#
#                                                       5  \
# 0                                                [-inf]
# 1                                                [-inf]
# 2                                                [-inf]
# 3                                                [-inf]
# 4                                                [-inf]
# ...                                                 ...
# 1995                                             [-inf]
# 1996  [-inf, 0.0, 2.0, 5.0, 10.0, 20.0, 32.0, 37.0, ...
# 1997                                       [-inf, 54.0]
# 1998                                             [-inf]
# 1999                                             [-inf]
#
#                                                       6  \
# 0                                                [-inf]
# 1                                                [-inf]
# 2                   [-inf, 5.0, 10.0, 15.0, 32.0, 54.0]
# 3     [-inf, 0.0, 13.0, 16.0, 18.0, 20.0, 23.0, 30.0...
# 4                                                [-inf]
# ...                                                 ...
# 1995  [-inf, 10.0, 17.0, 22.0, 56.0, 66.0, 85.0, 86....
# 1996                                             [-inf]
# 1997                                             [-inf]
# 1998                                             [-inf]
# 1999                                             [-inf]
#
#                                                7            8  \
# 0                                         [-inf]       [-inf]
# 1                                         [-inf]       [-inf]
# 2                                         [-inf]       [-inf]
# 3     [-inf, 11.0, 29.0, 38.0, 47.0, 69.0, 85.0]       [-inf]
# 4                                         [-inf]       [-inf]
# ...                                          ...          ...
# 1995                                      [-inf]       [-inf]
# 1996                                [-inf, 41.0]       [-inf]
# 1997                                      [-inf]       [-inf]
# 1998                                [-inf, 53.0]  [-inf, 7.0]
# 1999                                [-inf, 38.0]  [-inf, 2.0]
#
#                       9  ...  \
# 0                [-inf]  ...
# 1                [-inf]  ...
# 2     [-inf, 1.0, 17.0]  ...
# 3                [-inf]  ...
# 4                [-inf]  ...
# ...                 ...  ...
# 1995             [-inf]  ...
# 1996       [-inf, 54.0]  ...
# 1997             [-inf]  ...
# 1998             [-inf]  ...
# 1999             [-inf]  ...
#
#                                                     240     241  \
# 0                                          [-inf, 27.0]  [-inf]
# 1                                                [-inf]  [-inf]
# 2     [-inf, 4.0, 5.0, 16.0, 18.0, 21.0, 26.0, 33.0,...  [-inf]
# 3                                                [-inf]  [-inf]
# 4                                                [-inf]  [-inf]
# ...                                                 ...     ...
# 1995                                             [-inf]  [-inf]
# 1996                                             [-inf]  [-inf]
# 1997                                             [-inf]  [-inf]
# 1998                                             [-inf]  [-inf]
# 1999                                             [-inf]  [-inf]
#
#                                                     242           243  \
# 0                                                [-inf]  [-inf, 44.0]
# 1                                                [-inf]        [-inf]
# 2                                                [-inf]        [-inf]
# 3                                                [-inf]  [-inf, 57.0]
# 4                                                [-inf]        [-inf]
# ...                                                 ...           ...
# 1995                                             [-inf]        [-inf]
# 1996                           [-inf, 12.0, 19.0, 86.0]        [-inf]
# 1997                                             [-inf]        [-inf]
# 1998                                       [-inf, 25.0]        [-inf]
# 1999  [-inf, 2.0, 4.0, 7.0, 13.0, 14.0, 18.0, 21.0, ...  [-inf, 48.0]
#
#                                                  244  \
# 0     [-inf, 5.0, 8.0, 20.0, 37.0, 38.0, 56.0, 59.0]
# 1                                             [-inf]
# 2                                             [-inf]
# 3                                             [-inf]
# 4                                             [-inf]
# ...                                              ...
# 1995                                          [-inf]
# 1996                                          [-inf]
# 1997                                          [-inf]
# 1998                  [-inf, 34.0, 63.0, 67.0, 81.0]
# 1999                                          [-inf]
#
#                                                     245          246  \
# 0                                                [-inf]       [-inf]
# 1                                                [-inf]       [-inf]
# 2                                          [-inf, 75.0]       [-inf]
# 3                                    [-inf, 14.0, 87.0]       [-inf]
# 4                                                [-inf]       [-inf]
# ...                                                 ...          ...
# 1995                                             [-inf]       [-inf]
# 1996                                             [-inf]  [-inf, 6.0]
# 1997                                             [-inf]       [-inf]
# 1998                                             [-inf]       [-inf]
# 1999  [-inf, 5.0, 17.0, 22.0, 24.0, 25.0, 33.0, 49.0...       [-inf]
#
#                                                   247  \
# 0                                              [-inf]
# 1                                              [-inf]
# 2                                              [-inf]
# 3                                              [-inf]
# 4                                              [-inf]
# ...                                               ...
# 1995                                           [-inf]
# 1996                                           [-inf]
# 1997                                           [-inf]
# 1998  [-inf, 3.0, 17.0, 29.0, 30.0, 51.0, 58.0, 75.0]
# 1999                                           [-inf]
#
#                                                     248  \
# 0                                                [-inf]
# 1                                                [-inf]
# 2     [-inf, 3.0, 14.0, 20.0, 42.0, 45.0, 50.0, 51.0...
# 3     [-inf, 2.0, 5.0, 10.0, 23.0, 38.0, 44.0, 47.0,...
# 4                                                [-inf]
# ...                                                 ...
# 1995  [-inf, 0.0, 6.0, 8.0, 9.0, 15.0, 22.0, 37.0, 4...
# 1996                                             [-inf]
# 1997                                             [-inf]
# 1998                                             [-inf]
# 1999                                             [-inf]
#
#                                                     249
# 0     [-inf, 10.0, 26.0, 28.0, 32.0, 35.0, 40.0, 65....
# 1             [-inf, 4.0, 19.0, 22.0, 35.0, 79.0, 88.0]
# 2                   [-inf, 0.0, 23.0, 30.0, 31.0, 39.0]
# 3                              [-inf, 16.0, 51.0, 71.0]
# 4                                                [-inf]
# ...                                                 ...
# 1995                                             [-inf]
# 1996  [-inf, 0.0, 1.0, 4.0, 5.0, 7.0, 8.0, 10.0, 14....
# 1997  [-inf, 14.0, 28.0, 44.0, 45.0, 48.0, 50.0, 56....
# 1998                                             [-inf]
# 1999  [-inf, 8.0, 9.0, 11.0, 38.0, 39.0, 42.0, 43.0,...
#
# [2000 rows x 250 columns]

# %%
#histories.dump(EXPORT_PATH, which='mappings')
