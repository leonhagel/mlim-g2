# %% [markdown]
# ## **Predicting purchase probabilities**

# %% [markdown]
# ### **Loading the data**

# %%
import pandas as pd
import numpy as np

from classes import Helper, Purchase_Probabilities

# %%
DATA_PATH = '/Users/leonhagel/Documents/coding/github/mlim-g2/data/'
EXPORT_PATH = '/Users/leonhagel/Documents/coding/github/mlim-g2/export/'

# %%
files = {
    'data': [
        DATA_PATH + 'baskets.parquet',
        DATA_PATH + 'coupon_index.parquet', 
        DATA_PATH + 'coupons.parquet', 
        DATA_PATH + 'merged.parquet'
    ]
}

# %%
purchase = Purchase_Probabilities()
purchase.load(files)

# reduce file sizes
for name, df in purchase.data.items():
    purchase.data[name] = purchase.reduce_data_size(purchase.data[name])

# %% [markdown]
# <br>
#
# ### **Mappings**

# %% [markdown]
# **Price map and product histories**

# %%
purchase.data['clean'] = purchase.clean()

# %%
df_prices = purchase.data['merged'].copy()
df_prices = df_prices.loc[df_prices['price'].notna(), :]
df_prices.describe().round(2)
# Out:
#               week      shopper      product        price    discount
# count  68841598.00  68841598.00  68841598.00  68841598.00  2708043.00
# mean         44.50     50006.96       124.96       584.90       27.29
# std          25.98     28881.66        69.84        97.75        9.78
# min           0.00         0.00         0.00       234.00       10.00
# 25%          22.00     24981.00        66.00       506.00       20.00
# 50%          44.00     50019.00       123.00       579.00       30.00
# 75%          67.00     75041.00       189.00       654.00       35.00
# max          89.00     99999.00       249.00       837.00       40.00

# %%
df_purchased = purchase.data['clean'].copy()
df_purchased = df_purchased.loc[df_purchased['purchased'] == 1, :]
df_purchased.describe().round(2)
# Out:
#              week     shopper     product       price    discount  purchased
# count  1378720.00  1378720.00  1378720.00  1378720.00  1378720.00  1378720.0
# mean        44.48      997.21      125.07      590.73        0.01        1.0
# std         25.98      576.25       69.70       92.70        0.06        0.0
# min          0.00        0.00        0.00      389.23        0.00        1.0
# 25%         22.00      499.00       66.00      510.00        0.00        1.0
# 50%         44.00      993.00      123.00      582.00        0.00        1.0
# 75%         67.00     1496.00      189.00      657.00        0.00        1.0
# max         89.00     1999.00      249.00      837.65        0.40        1.0

# %%
map_config = {
    'product_histories': {'df': df_purchased, 'row_name': 'shopper', 'column_name': 'product', 'value_name': 'week', 'initial_array': [-np.inf]},
    'prices': {'df': df_prices, 'row_name': 'week', 'column_name': 'product', 'value_name': 'price', 'initial_array': []}
    #'prices': {'df': df_purchased, 'row_name': 'week', 'column_name': 'product', 'value_name': 'price', 'initial_array': []}
}

purchase.get_mappings(map_config)
# Out:
# 100%|██████████| 1378720/1378720 [00:42<00:00, 32370.43it/s]
# 100%|██████████| 68841598/68841598 [37:49<00:00, 30331.53it/s]

# %%
purchase.mappings['product_histories'].head()
# Out:
#                                            0  \
# 0                                     [-inf]
# 1  [-inf, 7.0, 11.0, 48.0, 61.0, 66.0, 81.0]
# 2                                     [-inf]
# 3                                     [-inf]
# 4                                     [-inf]
#
#                                                    1  \
# 0                                             [-inf]
# 1  [-inf, 2.0, 6.0, 18.0, 20.0, 27.0, 29.0, 49.0,...
# 2  [-inf, 2.0, 3.0, 6.0, 7.0, 8.0, 9.0, 11.0, 13....
# 3                                             [-inf]
# 4                                             [-inf]
#
#                                                    2       3  \
# 0                                             [-inf]  [-inf]
# 1                                             [-inf]  [-inf]
# 2                                             [-inf]  [-inf]
# 3                                             [-inf]  [-inf]
# 4  [-inf, 6.0, 15.0, 21.0, 22.0, 27.0, 28.0, 58.0...  [-inf]
#
#                                                    4       5  \
# 0  [-inf, 24.0, 40.0, 45.0, 51.0, 54.0, 58.0, 60....  [-inf]
# 1  [-inf, 5.0, 13.0, 21.0, 23.0, 30.0, 47.0, 69.0...  [-inf]
# 2                                             [-inf]  [-inf]
# 3                            [-inf, 7.0, 19.0, 27.0]  [-inf]
# 4                                             [-inf]  [-inf]
#
#                                                    6  \
# 0                                             [-inf]
# 1                                             [-inf]
# 2                [-inf, 5.0, 10.0, 15.0, 32.0, 54.0]
# 3  [-inf, 0.0, 13.0, 16.0, 18.0, 20.0, 23.0, 30.0...
# 4                                             [-inf]
#
#                                             7       8                  9  ...  \
# 0                                      [-inf]  [-inf]             [-inf]  ...
# 1                                      [-inf]  [-inf]             [-inf]  ...
# 2                                      [-inf]  [-inf]  [-inf, 1.0, 17.0]  ...
# 3  [-inf, 11.0, 29.0, 38.0, 47.0, 69.0, 85.0]  [-inf]             [-inf]  ...
# 4                                      [-inf]  [-inf]             [-inf]  ...
#
#                                                  240     241     242  \
# 0                                       [-inf, 27.0]  [-inf]  [-inf]
# 1                                             [-inf]  [-inf]  [-inf]
# 2  [-inf, 4.0, 5.0, 16.0, 18.0, 21.0, 26.0, 33.0,...  [-inf]  [-inf]
# 3                                             [-inf]  [-inf]  [-inf]
# 4                                             [-inf]  [-inf]  [-inf]
#
#             243                                             244  \
# 0  [-inf, 44.0]  [-inf, 5.0, 8.0, 20.0, 37.0, 38.0, 56.0, 59.0]
# 1        [-inf]                                          [-inf]
# 2        [-inf]                                          [-inf]
# 3  [-inf, 57.0]                                          [-inf]
# 4        [-inf]                                          [-inf]
#
#                   245     246     247  \
# 0              [-inf]  [-inf]  [-inf]
# 1              [-inf]  [-inf]  [-inf]
# 2        [-inf, 75.0]  [-inf]  [-inf]
# 3  [-inf, 14.0, 87.0]  [-inf]  [-inf]
# 4              [-inf]  [-inf]  [-inf]
#
#                                                  248  \
# 0                                             [-inf]
# 1                                             [-inf]
# 2  [-inf, 3.0, 14.0, 20.0, 42.0, 45.0, 50.0, 51.0...
# 3  [-inf, 2.0, 5.0, 10.0, 23.0, 38.0, 44.0, 47.0,...
# 4                                             [-inf]
#
#                                                  249
# 0  [-inf, 10.0, 26.0, 28.0, 32.0, 35.0, 40.0, 65....
# 1          [-inf, 4.0, 19.0, 22.0, 35.0, 79.0, 88.0]
# 2                [-inf, 0.0, 23.0, 30.0, 31.0, 39.0]
# 3                           [-inf, 16.0, 51.0, 71.0]
# 4                                             [-inf]
#
# [5 rows x 250 columns]

# %%
purchase.mappings['prices'].head()
# Out:
#                                                    0  \
# 0  [688.0, 688.0, 688.0, 688.0, 688.0, 688.0, 688...
# 1  [688.0, 688.0, 688.0, 688.0, 688.0, 688.0, 688...
# 2  [688.0, 688.0, 688.0, 688.0, 688.0, 688.0, 688...
# 3  [688.0, 688.0, 688.0, 688.0, 688.0, 447.0, 688...
# 4  [688.0, 688.0, 688.0, 688.0, 688.0, 688.0, 688...
#
#                                                    1  \
# 0  [560.0, 560.0, 560.0, 560.0, 560.0, 560.0, 560...
# 1  [560.0, 560.0, 560.0, 560.0, 560.0, 560.0, 560...
# 2  [560.0, 560.0, 560.0, 560.0, 560.0, 560.0, 560...
# 3  [560.0, 560.0, 560.0, 560.0, 560.0, 560.0, 560...
# 2  [528.0, 528.0, 528.0, 528.0, 369.0, 528.0, 528...
# 3  [528.0, 475.0, 528.0, 449.0, 528.0, 528.0, 528...
# 4  [528.0, 528.0, 449.0, 528.0, 528.0, 528.0, 528...
#
#                                                  241  \
# 0  [699.0, 699.0, 699.0, 699.0, 699.0, 454.0, 699...
# 1  [699.0, 699.0, 699.0, 699.0, 699.0, 699.0, 699...
# 2  [699.0, 699.0, 699.0, 699.0, 699.0, 699.0, 699...
# 3  [699.0, 699.0, 699.0, 699.0, 699.0, 699.0, 699...
# 4  [699.0, 699.0, 699.0, 699.0, 699.0, 699.0, 419...
#
#                                                  242  \
# 0  [511.0, 511.0, 511.0, 511.0, 511.0, 511.0, 511...
# 1  [511.0, 511.0, 511.0, 511.0, 511.0, 511.0, 511...
# 2  [511.0, 511.0, 511.0, 511.0, 511.0, 511.0, 511...
# 3  [511.0, 511.0, 511.0, 511.0, 511.0, 511.0, 511...
# 4  [511.0, 511.0, 358.0, 511.0, 511.0, 511.0, 511...
#
#                                                  243  \
# 0  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 1  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 2  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 3  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 4  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
#
#                                                  244  \
# 0  [694.0, 694.0, 694.0, 694.0, 694.0, 694.0, 694...
# 1  [694.0, 694.0, 694.0, 694.0, 694.0, 694.0, 694...
# 2  [694.0, 694.0, 694.0, 694.0, 694.0, 694.0, 694...
# 3  [694.0, 694.0, 694.0, 694.0, 694.0, 694.0, 694...
# 4  [694.0, 694.0, 694.0, 694.0, 694.0, 694.0, 694...
#
#                                                  245  \
# 0  [439.0, 549.0, 549.0, 549.0, 549.0, 549.0, 549...
# 1  [549.0, 549.0, 549.0, 549.0, 549.0, 549.0, 549...
# 2  [549.0, 549.0, 549.0, 549.0, 549.0, 549.0, 549...
# 3  [549.0, 549.0, 549.0, 549.0, 549.0, 549.0, 549...
# 4  [549.0, 549.0, 549.0, 549.0, 549.0, 549.0, 549...
#
#                                                  246  \
# 0  [702.0, 702.0, 702.0, 702.0, 702.0, 702.0, 702...
# 1  [702.0, 702.0, 702.0, 702.0, 702.0, 702.0, 702...
# 2  [702.0, 702.0, 702.0, 702.0, 702.0, 702.0, 702...
# 3  [702.0, 702.0, 702.0, 702.0, 702.0, 702.0, 702...
# 4  [702.0, 702.0, 702.0, 702.0, 702.0, 702.0, 702...
#
#                                                  247  \
# 0  [670.0, 670.0, 670.0, 670.0, 670.0, 670.0, 670...
# 1  [670.0, 670.0, 670.0, 670.0, 670.0, 670.0, 670...
# 2  [670.0, 670.0, 670.0, 670.0, 670.0, 670.0, 670...
# 3  [670.0, 670.0, 670.0, 670.0, 670.0, 670.0, 670...
# 4  [603.0, 670.0, 402.0, 670.0, 670.0, 670.0, 670...
#
#                                                  248  \
# 0  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 1  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 2  [490.0, 294.0, 490.0, 490.0, 490.0, 490.0, 490...
# 3  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
# 4  [490.0, 490.0, 490.0, 490.0, 490.0, 490.0, 490...
#
#                                                  249
# 0  [499.0, 499.0, 499.0, 499.0, 499.0, 499.0, 499...
# 1  [499.0, 499.0, 499.0, 499.0, 499.0, 499.0, 499...
# 2  [499.0, 499.0, 349.0, 449.0, 499.0, 374.0, 499...
# 3  [499.0, 499.0, 499.0, 499.0, 499.0, 499.0, 499...
# 4  [499.0, 499.0, 499.0, 499.0, 499.0, 499.0, 499...
#
# [5 rows x 250 columns]

# %%
purchase.dump(EXPORT_PATH, which='mappings')
